# %%
# I made a seperate python file I import here that has 3 dictionaries, with notes and their corresponding frequencies for 3 octaves

import noteDict as n
import numpy as np

# %%
# Making a numpy array for the song: Can You Dig It from Iron Man 3
# This is the Melody part

beatsPerMinute = 200 # MAKE SURE THIS IS THE SAME AS FOR THE BASS PART
secondsPerBeat = 1/beatsPerMinute * 60

Can_You_Dig_It_Melody = np.array([[ n.highOctave["A"], secondsPerBeat * 0.5 ]], dtype='float')
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 0.5 ]], axis=0) 
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D#"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D#"], secondsPerBeat * 0.5 ]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["F#"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C"], secondsPerBeat * 2 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 2 ]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 7 ]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 2]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["E"], secondsPerBeat * 7]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["E"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["A"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["F#"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 4.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ 0, secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["E"], 2/3*secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], 2/3*secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["G"], 2/3*secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["A"], secondsPerBeat * 2]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["F#"], secondsPerBeat * 0.5]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["G"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.highOctave["B"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["C#"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 1]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ n.HIGHOctave["E"], secondsPerBeat * 6]], axis=0)
Can_You_Dig_It_Melody = np.append(Can_You_Dig_It_Melody, [[ 0, secondsPerBeat * 0.5 ]], axis=0)

np.save('Can_You_Dig_It_Melody.npy', Can_You_Dig_It_Melody)

# %%
beatsPerMinute = 200 # MAKE SURE THIS IS THE SAME AS FOR THE MELODY PART
secondsPerBeat = 1/beatsPerMinute * 60

Can_You_Dig_It_Bass = np.array([[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], dtype='float')
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.5 ]], axis=0) 
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D#"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D#"], secondsPerBeat * 0.5 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["C"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["C"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["C"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["C"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["A"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["E"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.midOctave["D"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 2 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 2 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 1 ]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["B"], secondsPerBeat * 1 ]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["E"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["G"], secondsPerBeat * 0.5]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["G"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["G"], secondsPerBeat * 1]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 2]], axis=0)
Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ n.lowOctave["A"], secondsPerBeat * 5]], axis=0)

Can_You_Dig_It_Bass = np.append(Can_You_Dig_It_Bass, [[ 0, secondsPerBeat * 0.5 ]], axis=0)


np.save('Can_You_Dig_It_Bass.npy', Can_You_Dig_It_Bass)

# %%
# Making the shot files

shotHigh = np.array([[ n.highOctave["D"], 0.3 ]], dtype='float')
shotHigh = np.append(shotHigh, [[ n.highOctave["Eb"], 0.2 ]], axis=0)
shotHigh = np.append(shotHigh, [[ 0, 0.1 ]], axis=0)
shotHigh = np.append(shotHigh, [[ n.lowOctave["C"], 0.3 ]], axis=0)
shotHigh = np.append(shotHigh, [[ 0, 0.1 ]], axis=0)

shotLow = np.array([[ n.lowOctave["D"], 0.5]], dtype='float')
shotLow = np.append(shotLow, [[ 0, 0.1 ]], axis=0)
shotLow = np.append(shotLow, [[ n.lowOctave["C"], 0.3 ]], axis=0)
shotLow = np.append(shotLow, [[ 0, 0.1 ]], axis=0)

np.save('shotHigh.npy', shotHigh)
np.save('shotLow.npy', shotLow)

# %%
# Megalovania Melody

beatsPerMinute = 120 # MAKE SURE THIS IS THE SAME AS FOR THE MELODY PART
secondsPerBeat = 1/beatsPerMinute * 60

Megalovania_Melody = np.array([[ n.highOctave["D"], secondsPerBeat * 0.25 ]], dtype='float')
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.array([[ n.highOctave["D"], secondsPerBeat * 0.25 ]], dtype='float')
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.midOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.HIGHOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["A"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G#"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["F"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Melody = np.append(Megalovania_Melody, [[ n.highOctave["G"], secondsPerBeat * 0.25 ]], axis=0)

np.save('Megalovania_Melody.npy', Megalovania_Melody)

# %%
# Megalovania Melody

beatsPerMinute = 120 # MAKE SURE THIS IS THE SAME AS FOR THE MELODY PART
secondsPerBeat = 1/beatsPerMinute * 60

Megalovania_Bass = np.array([[ 0, secondsPerBeat * 16 ]], dtype='float')

Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["D"], secondsPerBeat * 0.5 ]], axis=0)

Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.midOctave["C"], secondsPerBeat * 0.5 ]], axis=0)

Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["B"], secondsPerBeat * 0.5 ]], axis=0)

Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.5 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ 0, secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.25 ]], axis=0)
Megalovania_Bass = np.append(Megalovania_Bass, [[ n.lowOctave["Bb"], secondsPerBeat * 0.5 ]], axis=0)

np.save('Megalovania_Bass.npy', Megalovania_Bass)
